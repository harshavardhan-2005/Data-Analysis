# %%
import requests as rq

# %%
pa=rq.get("https://randomfox.ca/floof")

# %%
print(pa.status_code)
# Out:
# 200

# %%
print(pa.text)
# Out:
# {"image":"https:\/\/randomfox.ca\/images\/51.jpg","link":"https:\/\/randomfox.ca\/?i=51"}

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '3913ab35-b954-4dc5-8e3a-b3bb132d82af',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-16T09:47:04.346Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 4861, 'name': 'syc2t7cik4m', 'symbol': 'noh942yliv', 'slug': '4gav0guj5dx', 'cmc_rank': 2111, 'num_market_pairs': 6290, 'circulating_supply': 7200, 'total_supply': 7867, 'max_supply': 5499, 'infinite_supply': None, 'last_updated': '2024-02-16T09:47:04.346Z', 'date_added': '2024-02-16T09:47:04.346Z', 'tags': ['ib8qe0u4zo', 'w14tcqdlfy', 'cv9pmbvdzie', 'dm9qm0kujog', 'ptlujjmr7dl', 'dsmcnzwkk7', 'r0t0lf5jr5', 'yoekaloyn4i', '5ak5rfe26eq', 'aebtvygr93g'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.3340771467539507, 'volume_24h': 3114, 'volume_change_24h': 0.7943707487638709, 'percent_change_1h': 0.7914327748413672, 'percent_change_24h': 0.8393008518557696, 'percent_change_7d': 0.39114993456557423, 'market_cap': 0.06567187709432765, 'market_cap_dominance': 9870, 'fully_diluted_market_cap': 0.7626189213606269, 'last_updated': '2024-02-16T09:47:04.346Z'}}}, {'id': 8388, 'name': '2rxexfw5dip', 'symbol': '1lfmppvdnxu', 'slug': 'rddmxczjsl', 'cmc_rank': 5300, 'num_market_pairs': 6418, 'circulating_supply': 7438, 'total_supply': 3971, 'max_supply': 2264, 'infinite_supply': None, 'last_updated': '2024-02-16T09:47:04.346Z', 'date_added': '2024-02-16T09:47:04.346Z', 'tags': ['8pvqvxc4ysi', 'fg2p430full', 'zv6uwkq3brh', 'y2ac6a3zwed', 'g615h0fa6o', '3c2g0wf3xn4', 'p9xsunjf0fn', 'aagew31gngw', 'txu9cgzbnlo', '7fdgk5w6i7c'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.7015917690648601, 'volume_24h': 6692, 'volume_change_24h': 0.7829196232561704, 'percent_change_1h': 0.9983173146285182, 'percent_change_24h': 0.01912167067690418, 'percent_change_7d': 0.633713048562472, 'market_cap': 0.9505378406175653, 'market_cap_dominance': 9838, 'fully_diluted_market_cap': 0.0879253288878894, 'last_updated': '2024-02-16T09:47:04.346Z'}}}, {'id': 1365, 'name': 'hsqyb19l5i', 'symbol': 'bwk01e6se78', 'slug': '7yg24cq22ki', 'cmc_rank': 6850, 'num_market_pairs': 3770, 'circulating_supply': 561, 'total_supply': 9254, 'max_supply': 8820, 'infinite_supply': None, 'last_updated': '2024-02-16T09:47:04.346Z', 'date_added': '2024-02-16T09:47:04.346Z', 'tags': ['6ro1f97glbm', '0eqwirrroma', 'v1h5fljxqk', 'b90rqq9fayd', 'apd58zlqkua', 'dqt0kivwhft', 'wz642pps2wq', '36x7pij10tj', '7isi6j0tuz6', 'f0ad0etp18u'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.753508165074221, 'volume_24h': 1947, 'volume_change_24h': 0.3380488938340265, 'percent_change_1h': 0.004943537580295976, 'percent_change_24h': 0.36573696621325125, 'percent_change_7d': 0.49294819069290674, 'market_cap': 0.7986012622133838, 'market_cap_dominance': 6219, 'fully_diluted_market_cap': 0.8575473468544108, 'last_updated': '2024-02-16T09:47:04.346Z'}}}, {'id': 8790, 'name': '76qenxswmqb', 'symbol': 'gmvmbqaphqd', 'slug': 'uwefr31otu', 'cmc_rank': 134, 'num_market_pairs': 4333, 'circulating_supply': 176, 'total_supply': 4358, 'max_supply': 1382, 'infinite_supply': None, 'last_updated': '2024-02-16T09:47:04.346Z', 'date_added': '2024-02-16T09:47:04.346Z', 'tags': ['0w73bkpegybn', '0ctak73oat', 'iapyryuir9', '0w8un1fdtwko', 'typ1f8s27x', 'vjkij8sa1pi', '0eao52k8emj', 'mhipe8yupzj', '2v8vmj1jkzb', '7oulml0p6fd'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.11178460639841226, 'volume_24h': 5427, 'volume_change_24h': 0.2480009389372202, 'percent_change_1h': 0.666479125178632, 'percent_change_24h': 0.4809712091268523, 'percent_change_7d': 0.5981632809268809, 'market_cap': 0.8388518340640871, 'market_cap_dominance': 1321, 'fully_diluted_market_cap': 0.7703907245733683, 'last_updated': '2024-02-16T09:47:04.346Z'}}}, {'id': 5581, 'name': 'rbxwei5g1mc', 'symb ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm= pd.json_normalize(data['data'])

# %%
norm
# Out:
#      id         name       symbol         slug  cmc_rank  num_market_pairs  \
# 0  4861  syc2t7cik4m   noh942yliv  4gav0guj5dx      2111              6290
# 1  8388  2rxexfw5dip  1lfmppvdnxu   rddmxczjsl      5300              6418
# 2  1365   hsqyb19l5i  bwk01e6se78  7yg24cq22ki      6850              3770
# 3  8790  76qenxswmqb  gmvmbqaphqd   uwefr31otu       134              4333
# 4  5581  rbxwei5g1mc  k631w3pqdgh  cux0h5dzra5      3056               799
# 5  8852   hfg268pucp  69laamo1alx  07gs6i8zc1i      1957              9016
# 6  5118  dlky15xsafp  9pdmmkc865h  araqt2c2pet      5340              7394
# 7  7630   3ofv8srqv5   yrvqqwd50p  22pxzyxkhlt      6202              6595
# 8  7444  b7l7s34ss4t  8xvwo6rs565  ziwj4b479sl       671              8136
# 9  8539  cw0db7j7rrl  8mtmhhkxy8k  n0pchsz1ibd      8088               591
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# 0                7200          7867        5499            None  ...
# 1                7438          3971        2264            None  ...
# 2                 561          9254        8820            None  ...
# 3                 176          4358        1382            None  ...
# 4                 219          8048        9333            None  ...
# 5                5221          9866        5033            None  ...
# 6                3447          2070        1901            None  ...
# 7                7435          4396        7605            None  ...
# 8                 103          1106        7912            None  ...
# 9                9006          3168        9607            None  ...
#
#   quote.USD.price quote.USD.volume_24h quote.USD.volume_change_24h  \
# 0        0.334077                 3114                    0.794371
# 1        0.701592                 6692                    0.782920
# 2        0.753508                 1947                    0.338049
# 3        0.111785                 5427                    0.248001
# 4        0.684401                 8651                    0.764264
# 5        0.128800                 8755                    0.774632
# 6        0.770398                  645                    0.332540
# 7        0.837145                 5986                    0.185545
# 8        0.034569                 5793                    0.261854
# 9        0.981546                 4199                    0.482295
#
#   quote.USD.percent_change_1h quote.USD.percent_change_24h  \
# 0                    0.791433                     0.839301
# 1                    0.998317                     0.019122
# 2                    0.004944                     0.365737
# 3                    0.666479                     0.480971
# 4                    0.767640                     0.118805
# 5                    0.259561                     0.173136
# 6                    0.486534                     0.517396
# 7                    0.413048                     0.079573
# 8                    0.594688                     0.162642
# 9                    0.760301                     0.541184
#
#   quote.USD.percent_change_7d  quote.USD.market_cap  \
# 0                    0.391150              0.065672
# 1                    0.633713              0.950538
# 2                    0.492948              0.798601
# 3                    0.598163              0.838852
# 4                    0.163979              0.348849
# 5                    0.557009              0.453175
# 6                    0.567921              0.903272
# 7                    0.970707              0.007301
# 8                    0.850817              0.909978
# 9                    0.643533              0.608114
#
#    quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                            9870                            0.762619
# 1                            9838                            0.087925
# 2                            6219                            0.857547
# 3                            1321                            0.770391
# 4                            7304                            0.820690
# 5                            7130                            0.044942
# 6                            6475                            0.680365
# 7                            7011                            0.899123
# 8                            4046                            0.386725
# 9                            8836                            0.905925
#
#      quote.USD.last_updated
# 0  2024-02-16T09:47:04.346Z
# 1  2024-02-16T09:47:04.346Z
# 2  2024-02-16T09:47:04.346Z
# 3  2024-02-16T09:47:04.346Z
# 4  2024-02-16T09:47:04.346Z
# 5  2024-02-16T09:47:04.346Z
# 6  2024-02-16T09:47:04.346Z
# 7  2024-02-16T09:47:04.346Z
# 8  2024-02-16T09:47:04.346Z
# 9  2024-02-16T09:47:04.346Z
#
# [10 rows x 26 columns]

# %% [markdown]
# case1 :
#
# machine learning
#
# >

# %%
*

# %% [markdown]
# Extracting data from CoinMarket cap API:
#
# Program Flow:
#
# 1. Go to Coinmarket cap website
#
# 2. Go to Products--> API and obtain API key
#
# 3. Go to documentation to obtain API code!
#
# 4. Know your code!
#
# 5. Run it in any python environment
#
# 6. Obtain data in the form of json
#
# 7. Normalize the data into a dataframe
#
# 8. Save it if you needed
