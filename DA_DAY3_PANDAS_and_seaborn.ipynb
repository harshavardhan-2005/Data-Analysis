# %% [markdown]
# PANDAS
#
#
# *   Pandas are used to load data into our program
# ist item
# *   DATA Frames-Are used to store data in tables with rows and columns readable by python
#
# *   used for data manipulation
# -data frames
# -data cleaning by dropping or replacing with mean

# %%
import pandas as pd

# %%
names=["Jwalitha","Ramya","kusuma"]
index=[40,42,44]
ser1=pd.Series(names,index)
print(ser1)
# Out:
# 40    Jwalitha
# 42       Ramya
# 44      kusuma
# dtype: object

# %% [markdown]
# importing files
#
# *   for csvmand txt:read_csv("file path")
# *   for excel: read_excel("file path")

# %%
df=pd.read_csv("/content/diabetcsv.csv")
df.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive
# 5     5   116    74     0     0  25.6  0.201   30  tested_negative
# 6     3    78    50    32    88  31.0  0.248   26  tested_positive
# 7    10   115     0     0     0  35.3  0.134   29  tested_negative
# 8     2   197    70    45   543  30.5  0.158   53  tested_positive
# 9     8   125    96     0     0   0.0  0.232   54  tested_positive

# %%
df.tail()
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative

# %%
dft=pd.read_csv("/content/grades1.txt",sep=" ")

# %%
dft.head(16)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade
# 0      Joe        K   9.8  10.0   9.9    A+
# 1   Rajesh        M   8.9   9.1   9.3     A
# 2   Kissan        V   9.9   9.3   9.2     A
# 3     Mary        N   7.7   8.0   7.1     B
# 4     Jeen        K   9.8   9.1   9.9    A+
# 5      Raj        M   8.9   9.1   9.3     A
# 6   Hassan        V   9.9   9.0   9.2     A
# 7     Mari        N   7.7   8.0   7.1     B
# 8     Jess        K   9.8   9.1   9.9    A+
# 9   Rajini        M   7.0   9.1   9.3     A
# 10   Kiran        V   9.9   9.3   9.2     A
# 11    Maya        N   7.7   8.0   7.1     B
# 12   Jolin        K   9.8   9.1   9.9    A+
# 13    Riya        M   8.0   9.1   9.3     A
# 14    Sana        V   9.9   9.3   9.2     A
# 15    Mark        N   7.7   8.0   7.0     B

# %%
dfe=pd.read_excel("/content/diabetes.xlsx")

# %%
dfe.head(15)
# Out:
#     preg  plas  pres  skin  insu  mass   pedi  age            class
# 0      6   148    72    35     0  33.6  0.627   50  tested_positive
# 1      1    85    66    29     0  26.6  0.351   31  tested_negative
# 2      8   183    64     0     0  23.3  0.672   32  tested_positive
# 3      1    89    66    23    94  28.1  0.167   21  tested_negative
# 4      0   137    40    35   168  43.1  2.288   33  tested_positive
# 5      5   116    74     0     0  25.6  0.201   30  tested_negative
# 6      3    78    50    32    88  31.0  0.248   26  tested_positive
# 7     10   115     0     0     0  35.3  0.134   29  tested_negative
# 8      2   197    70    45   543  30.5  0.158   53  tested_positive
# 9      8   125    96     0     0   0.0  0.232   54  tested_positive
# 10     4   110    92     0     0  37.6  0.191   30  tested_negative
# 11    10   168    74     0     0  38.0  0.537   34  tested_positive
# 12    10   139    80     0     0  27.1  1.441   57  tested_negative
# ...

# %%
print(df.shape)#rows and columns
# Out:
# (768, 9)

# %%
print(df.shape[0])#no of rows only
# Out:
# 768

# %%
print(df.shape[1])#no of columns
# Out:
# 9

# %%
print(dft.shape)#rows and columns
print(dft.shape[0])#no of rows only
print(dft.shape[1])#no of columns
# Out:
# (16, 6)
# 16
# 6

# %%
print(dfe.shape)#rows and columns
print(dfe.shape[0])#no of rows only
print(dfe.shape[1])#no of columns
# Out:
# (768, 9)
# 768
# 9

# %% [markdown]
# Accessing Data
#
#
# *   loc=accepts column names and index
# *   iloc=accepts only index

# %%
print(dft.loc[2:5,"Names"]) #rows of specified column
# Out:
# 2    Kissan
# 3      Mary
# 4      Jeen
# 5       Raj
# Name: Names, dtype: object

# %%
print(dft.iloc[2:5, :3])
# Out:
#     Names Initials  SEM1
# 2  Kissan        V   9.9
# 3    Mary        N   7.7
# 4    Jeen        K   9.8

# %%
dfn=pd.read_csv("/content/grades_withnulls.csv")

# %%
dfn.isnull()
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# ...

# %%
dfn.isnull().sum()#to view how many nulls we have per column
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
dfn.isnull().sum().sum()#to view total nulls
# Out:
# 4

# %%
dfc=dfn.dropna() #dropping all the rows with nulls

# %%
dfc
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfc1=dfn.fillna(7)
dfc1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   7.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   7.0   9.1   9.9    A+       1
# 9   Rajini        M   7.0   9.1   9.3     A       0
# 10   Kiran        V   7.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
m=dfn['SEM3'].mean()
print(m)
# Out:
# 9.100000000000001

# %%
dfc2=dfn.fillna(m)
(dfc2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-22bef38662be> in <cell line: 1>()
# ----> 1 dfc2=dfn.fillna(m)
#       2 (dfc2)
#
# NameError: name 'dfn' is not defined

# %%
c=dfc2.drop_duplicates()
print(c)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.1     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.1   9.1   9.9    A+       1
# 9   Rajini        M   9.1   9.1   9.3     A       0
# 10   Kiran        V   9.1   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfc2.rename(columns ={"GRADE":"GPA"}) # df.name(column name = { old:new})
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   9.1     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   9.1   9.1   9.9    A+       1
# 9   Rajini        M   9.1   9.1   9.3     A       0
# 10   Kiran        V   9.1   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dfc2.rename(columns ={"GRADE":"GPA"} ) # df.name(column name = { old:new})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8b7f6e36c2a6> in <cell line: 1>()
# ----> 1 dfc2.rename(columns ={"GRADE":"GPA"} ) # df.name(column name = { old:new})
#
# NameError: name 'dfc2' is not defined

# %%
dfc2.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 3    Mary        N   7.7   8.0   9.1     B       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1

# %%
dfc2[['SEM1','SEM2']].plot.line()
# Out:
# <Axes: >

# %%
dfc2.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
import seaborn as sns

# %%
p1=sns.lineplot(x="Names",y='SEM1',data=dfc2)

# %%
sns.relplot(
    data=dfc2,
    x='SEM2',y='SEM1',col='Placed')

# %% [markdown]
# load diabetictes.csv
#
#
# *   create a replot with the index in the x- axis
# *   age in y axis

# %%
dc=pd.read_csv("/content/diabetcsv.csv")
dc
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
dc['index']=range(0,768)
sns.relplot(
    data=dc,
    x='index',y='age',col='class')

# %% [markdown]
# in built data sets in seaborn
# TIPS
#
# *   dowjones
#
# *   fmri
# *   dots
#
#
# *   healthexp
#
#
# to load these ldata sets use load_dataset("data_setname")

# %%
tips=sns.load_dataset("tips")

# %%
tips.head(243)
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [243 rows x 7 columns]

# %%
tips['index']=range(0,244)
a=input("enter the situation")
sns.relplot(
    data=tips,
    x='total_bill',y='tip',hue=a)
# Out:
# enter the situationsize

# %% [markdown]
# hue = diferent colour for diff category
#
# style= to give diff shapes

# %%
a=input("enter the situation")
sns.relplot(
    data=tips,
    x='total_bill',y='tip',hue=a, style='day')
# Out:
# enter the situationday

# %% [markdown]
# dowjones

# %%
dj=sns.load_dataset("dowjones")

# %%
dj.head(669)
# Out:
#           Date   Price
# 0   1914-12-01   55.00
# 1   1915-01-01   56.55
# 2   1915-02-01   56.00
# 3   1915-03-01   58.30
# 4   1915-04-01   66.45
# ..         ...     ...
# 644 1968-08-01  883.72
# 645 1968-09-01  922.80
# 646 1968-10-01  955.47
# 647 1968-11-01  964.12
# 648 1968-12-01  965.39
#
# [649 rows x 2 columns]

# %%
sns.catplot(data=tips,x="total_bill",y="day")

# %%
sns.lineplot(
    data=dj,
    x='Date',y='Price')
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %%
sns.catplot(data=tips,y="total_bill",x="time",hue="smoker",kind="violin")

# %% [markdown]
# liner regression
#
# plot name is linear fit
#
# (implot create a function)
#
# ploting a data set
#
# fitting the line
#
# prediction

# %%
sns.lmplot(x="total_bill",y="tip",data=tips)

# %%
fr=sns.load_dataset("fmri")
fr.head(1064)
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.barplot(data=fr,x="timepoint",y="signal",hue="event")
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>
